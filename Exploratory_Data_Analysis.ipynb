# %% [markdown]
# <a href="https://colab.research.google.com/github/ncc-chandni/Projects/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import and Export of Petroleum Products
#
# Import & Export of Petroleum Products
#
# Released Under: National Data Sharing and Accessibility Policy (NDSAP)
#
# Contributor: Ministry of Petroleum and Natural Gas Petroleum Planning & Analysis Cell (PPAC)
#
# Domain: Open Government Data (OGD) Platform India
# Published On: 27/04/2023
#
# Updated On: 22/06/2023

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/im202223.csv')

# %%
df.head(5)
# Out:
#   IMPORT/EXPORT (Quantity in '000 Metric Tonnes)     PRODUCT  APRIL    MAY  \
# 0                                         IMPORT   CRUDE OIL  21626  19644
# 1                                         IMPORT         LPG   1605   1363
# 2                                         IMPORT          MS      0     30
# 3                                         IMPORT     Naphtha     35     30
# 4                                         IMPORT         ATF      0      0
#
#     JUNE   JULY  AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  JANUARY  \
# 0  19441  20624   17637      16772    18123     19003     19618    20058
# 1   1264   1417    1574       1448     1374      1778      1718     1709
# 2    127     63       0        190      327       211       120        0
# 3      2    145      90         76      135        28        88       67
# 4      0      0       0          0        0         0         0        0
#
#    FEBRUARY  MARCH   TOTAL
# 0     19285  20729  232561
# ...

# %%
df.shape
# Out:
# (28, 15)

# %%
df
# Out:
#    IMPORT/EXPORT (Quantity in '000 Metric Tonnes)                PRODUCT  \
# 0                                          IMPORT              CRUDE OIL
# 1                                          IMPORT                    LPG
# 2                                          IMPORT                     MS
# 3                                          IMPORT                Naphtha
# 4                                          IMPORT                    ATF
# 5                                          IMPORT                    SKO
# 6                                          IMPORT                    HSD
# 7                                          IMPORT         LOBS/ Lube oil
# 8                                          IMPORT               Fuel Oil
# 9                                          IMPORT                Bitumen
# 10                                         IMPORT                Petcoke
# 11                                         IMPORT                Others&
# ...

# %%
df.isnull().sum()
# Out:
# IMPORT/EXPORT (Quantity in '000 Metric Tonnes)    0
# PRODUCT                                           0
# APRIL                                             0
# MAY                                               0
# JUNE                                              0
# JULY                                              0
# AUGUST                                            0
# SEPTEMBER                                         0
# OCTOBER                                           0
# NOVEMBER                                          0
# DECEMBER                                          0
# JANUARY                                           0
# FEBRUARY                                          0
# MARCH                                             0
# TOTAL                                             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['IMPORT/EXPORT (Quantity in '000 Metric Tonnes)', 'PRODUCT', 'APRIL',
#        'MAY', 'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVEMBER',
#        'DECEMBER', 'JANUARY', 'FEBRUARY', 'MARCH', 'TOTAL'],
#       dtype='object')

# %%
df.rename(columns={"IMPORT/EXPORT (Quantity in '000 Metric Tonnes)" : 'Import/Export' }, inplace = True)

# %%
df.head(5)
# Out:
#   Import/Export     PRODUCT  APRIL    MAY   JUNE   JULY  AUGUST  SEPTEMBER  \
# 0        IMPORT   CRUDE OIL  21626  19644  19441  20624   17637      16772
# 1        IMPORT         LPG   1605   1363   1264   1417    1574       1448
# 2        IMPORT          MS      0     30    127     63       0        190
# 3        IMPORT     Naphtha     35     30      2    145      90         76
# 4        IMPORT         ATF      0      0      0      0       0          0
#
#    OCTOBER  NOVEMBER  DECEMBER  JANUARY  FEBRUARY  MARCH   TOTAL
# 0    18123     19003     19618    20058     19285  20729  232561
# 1     1374      1778      1718     1709      1647   1410   18309
# 2      327       211       120        0         0      0    1069
# 3      135        28        88       67       121    117     936
# 4        0         0         0        0         0      0       0

# %%
df.describe()
# Out:
#               APRIL           MAY          JUNE          JULY        AUGUST  \
# count     28.000000     28.000000     28.000000     28.000000     28.000000
# mean    3107.892857   2776.964286   2728.142857   2911.321429   2535.214286
# std     7042.564555   6237.017981   6152.418246   6706.813004   5636.422752
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.750000     24.750000     27.500000     33.500000      6.000000
# 50%      244.000000    232.500000    195.500000    200.000000    193.000000
# 75%     1452.750000   1208.500000   1187.500000   1186.000000   1157.000000
# max    25803.000000  22929.000000  22581.000000  24363.000000  20846.000000
#
#           SEPTEMBER       OCTOBER      NOVEMBER      DECEMBER       JANUARY  \
# count     28.000000     28.000000     28.000000     28.000000     28.000000
# mean    2426.678571   2639.428571   2765.392857   2883.785714   2870.928571
# ...

# %% [markdown]
# Trend Analysis

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df.drop(['PRODUCT'], axis = 1), markers = True)
plt.xlabel("Month")
plt.ylabel("Import Quantity")
plt.legend(title = "Product", bbox_to_anchor=(1,1))
plt.show()
